# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
li = [[1000,1000,1000,1000],[2000,0,0,500],[2000,0,0,0],[100,500,0,0]]
u1 = (1000+0+1000+2000)//4
u2 = (1000+500+1000+0)//4
u3 = (2000+0+1000+500)//4
u4 = (875+0+625+0)//4
print(f'At i = 0 ->', u1, u2, u3, u4)
for i in range(5):
    u1 = (1000+u2+u3+2000)//4
    u2 = (u1 + 500 +1000+ u4)//4
    u3 = (2000+u4+u1+500)//4
    u4 = (u3+0+u2+ 0 )//4
    print(f'At i = {i+1} ->', u1, u2, u3, u4)
# Out:
# At i = 0 -> 1000 625 875 375
# At i = 1 -> 1125 750 1000 437
# At i = 2 -> 1187 781 1031 453
# At i = 3 -> 1203 789 1039 457
# At i = 4 -> 1207 791 1041 458
# At i = 5 -> 1208 791 1041 458
