# %%
import matplotlib.pyplot as plt
import numpy as np
def function(x):
    return -3.5*x*x + 14.5 * x - 10

x = np.arange(0,4,0.01)
y = [function(i) for i in x]
x_p = [1,2,3]
y_p = [1,5,2]
plt.plot(x,y)
plt.scatter(x_p, y_p)

# %%
import pandas as pd
def inv_interpol(data, y):
    x_result = 0
    for i in df.index:
        x_i = df['X'][i]
        for j in df.index:
            if i != j:
                x_i = x_i * (y - df['Y'][j])/(df['Y'][i] - df['Y'][j])
        x_result += x_i
    return x_result

data = {'X' : [1.27, 2.25, 2.5, 3.6], 'Y' : [2.3, 2.95, 3.5, 5.1]}
df = pd.DataFrame(data)
y = 4.5
print(inv_interpol(data, y))
df
# Out:
# 2.795005430615897
#       X     Y
# 0  1.27  2.30
# 1  2.25  2.95
# 2  2.50  3.50
# 3  3.60  5.10
